# %%
import pandas as pd

# %%
df1 = pd.read_csv('file1.csv')

# %%
df1.head()
# Out:
#        date  price
# 0  20140101      1
# 1  20140201      2
# 2  20140301      3

# %%
df2 = pd.read_csv('file2.csv')

# %%
df2.head()
# Out:
#        date  price
# 0  20140401      4
# 1  20140501      5
# 2  20140601      6

# %%
df3 = pd.concat([df1, df2])

# %%
df3.head()
# Out:
#        date  price
# 0  20140101      1
# 1  20140201      2
# 2  20140301      3
# 0  20140401      4
# 1  20140501      5

# %%
df3.dtypes
# Out:
# date     int64
# price    int64
# dtype: object
