# %% [markdown]
# # Perform statistical analyses

# %% [markdown]
# # Document
#
# <table align="left">
#     <tr>
#         <th class="text-align:left">Title</th>
#         <td class="text-align:left">Perform statistical analyses</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Last modified</th>
#         <td class="text-align:left">2019-01-09</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Author</th>
#         <td class="text-align:left">Gilles Pilon <gillespilon13@gmail.com></td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Status</th>
#         <td class="text-align:left">Active</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Type</th>
#         <td class="text-align:left">Jupyter notebook</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Created</th>
#         <td class="text-align:left">2018-12-21</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">File name</th>
#         <td class="text-align:left">N/A</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Other files required</th>
#         <td class="text-align:left">N/A</td>
#     </tr>
# </table>

# %% [markdown]
# # Ideas
#
# - Built-in statistics.
# - Parametric statistics.
# - Non-parametric statistics.
# - Simple linear regression.

# %%
import pandas as pd

# %%
# Read a csv file. This file is raw, not munged.
FILE_TO_READ = 'thirteen_weeks.csv'
df = pd.read_csv(FILE_TO_READ,
                 parse_dates=True,
                 index_col='Time')

# %%
df.dtypes
# Out:
# Water Load (lb/MSF)            float64
# Trim Board Density (lb/cft)     object
# Trim Board Thickness (in)       object
# Trim Board Weight (lb/sft)      object
# Wool Target (%)                 object
# Wool Usage (%)                 float64
# Wool Flow (lb/min)             float64
# Starch Target (%)               object
# Starch Usage (%)               float64
# Starch Flow (lb/min)           float64
# Clay Target (%)                 object
# Clay Usage (%)                   int64
# Clay Flow (lb/min)             float64
# Newsprint Target (%)            object
# Newsprint Usage (%)            float64
# Perlite Target (%)              object
# Perlite Usage (%)              float64
# Wet Clay Target (%)             object
# Wet Clay Usage (%)               int64
# Wet Gypsum Target (%)           object
# Wet Gypsum Usage (%)             int64
# Wet Broke Target (%)            object
# Wet Broke Usage (%)            float64
# Dust Target (%)                 object
# Dust Usage (%)                 float64
# Broke Target (%)                object
# Broke Usage (%)                float64
# Consistency Target (%)         float64
# Consistency Actual (%)           int64
# dtype: object

# %%
# For a single numeric column.
df['Water Load (lb/MSF)'].describe()
# Out:
# count    4275.000000
# mean     1088.845725
# std       128.663227
# min       943.770019
# 25%      1012.230042
# 50%      1041.569946
# 75%      1075.800049
# max      1486.560059
# Name: Water Load (lb/MSF), dtype: float64

# %%
# For a single object column.
df['Trim Board Density (lb/cft)'].describe()
# Out:
# count            4275
# unique            590
# top       11.97699928
# freq              390
# Name: Trim Board Density (lb/cft), dtype: object

# %%
# For all columns in a dataframe. Only numeric fields are returned.
df.describe()
# Out:
#        Water Load (lb/MSF)  Wool Usage (%)  Wool Flow (lb/min)  \
# count          4275.000000     4275.000000         4275.000000
# mean           1088.845725      258.104949           23.932503
# std             128.663227      901.637413           27.605636
# min             943.770019        0.000000            0.000042
# 25%            1012.230042        4.163668            0.077812
# 50%            1041.569946       17.559425            0.470875
# 75%            1075.800049       20.963467           52.839138
# max            1486.560059     7352.957031          232.154449
#
#        Starch Usage (%)  Starch Flow (lb/min)  Clay Usage (%)  \
# count      4.275000e+03           4275.000000          4275.0
# mean       2.933942e+17             14.815349             0.0
# std        1.918313e+19             14.321005             0.0
# min       -4.254367e+01             -1.235398             0.0
# 25%        1.169661e+00             -0.168050             0.0
# 50%        9.867329e+00              6.758324             0.0
# 75%        1.034410e+01             29.850600             0.0
# max        1.254260e+21             45.670250             0.0
#
#        Clay Flow (lb/min)  Newsprint Usage (%)  Perlite Usage (%)  \
# count         4275.000000          4275.000000        4275.000000
# mean            -0.458074             9.059988          54.142210
# std              1.066906            12.851066         300.750791
# min             -1.237608             0.000000        -665.383606
# 25%             -1.206861             0.044219           1.708141
# 50%             -0.929585            10.594168          57.176479
# 75%             -0.127090            13.993915          58.816626
# max              3.207253           100.126297       15425.487300
#
#        Wet Clay Usage (%)  Wet Gypsum Usage (%)  Wet Broke Usage (%)  \
# count              4275.0                4275.0          4275.000000
# mean                  0.0                   0.0             0.792902
# std                   0.0                   0.0             3.276198
# min                   0.0                   0.0            -0.000856
# 25%                   0.0                   0.0             0.001372
# 50%                   0.0                   0.0             0.005100
# 75%                   0.0                   0.0             0.257903
# max                   0.0                   0.0           100.278595
#
#        Dust Usage (%)  Broke Usage (%)  Consistency Target (%)  \
# count     4275.000000      4275.000000             4275.000000
# mean        12.687469         2.382471                2.382471
# std         33.573087         4.061182                4.061182
# min          0.000077        -5.000071               -5.000071
# 25%          0.329074         0.000000                0.000000
# 50%          9.200419         0.003685                0.003685
# 75%         13.778525         4.528879                4.528879
# max        305.015625        60.165688               60.165688
#
#        Consistency Actual (%)
# count                  4275.0
# mean                      0.0
# std                       0.0
# min                       0.0
# 25%                       0.0
# 50%                       0.0
# 75%                       0.0
# max                       0.0

# %%
# Describe all columns regardless of data type.
df.describe(include='all')
# Out:
#         Water Load (lb/MSF) Trim Board Density (lb/cft)  \
# count           4275.000000                        4275
# unique                  NaN                         590
# top                     NaN                 11.97699928
# freq                    NaN                         390
# mean            1088.845725                         NaN
# std              128.663227                         NaN
# min              943.770019                         NaN
# 25%             1012.230042                         NaN
# 50%             1041.569946                         NaN
# 75%             1075.800049                         NaN
# max             1486.560059                         NaN
#
#        Trim Board Thickness (in) Trim Board Weight (lb/sft) Wool Target (%)  \
# count                       4275                       4275            4275
# unique                        42                        100               4
# top                  0.595000029                58.79999924         No Data
# freq                         555                        405            3149
# mean                         NaN                        NaN             NaN
# std                          NaN                        NaN             NaN
# min                          NaN                        NaN             NaN
# 25%                          NaN                        NaN             NaN
# 50%                          NaN                        NaN             NaN
# 75%                          NaN                        NaN             NaN
# max                          NaN                        NaN             NaN
#
#         Wool Usage (%)  Wool Flow (lb/min) Starch Target (%)  \
# count      4275.000000         4275.000000              4275
# unique             NaN                 NaN                 2
# top                NaN                 NaN           No Data
# freq               NaN                 NaN              3149
# mean        258.104949           23.932503               NaN
# std         901.637413           27.605636               NaN
# min           0.000000            0.000042               NaN
# 25%           4.163668            0.077812               NaN
# 50%          17.559425            0.470875               NaN
# 75%          20.963467           52.839138               NaN
# max        7352.957031          232.154449               NaN
#
#         Starch Usage (%)  Starch Flow (lb/min)          ...            \
# count       4.275000e+03           4275.000000          ...
# unique               NaN                   NaN          ...
# top                  NaN                   NaN          ...
# freq                 NaN                   NaN          ...
# mean        2.933942e+17             14.815349          ...
# std         1.918313e+19             14.321005          ...
# min        -4.254367e+01             -1.235398          ...
# 25%         1.169661e+00             -0.168050          ...
# 50%         9.867329e+00              6.758324          ...
# 75%         1.034410e+01             29.850600          ...
# max         1.254260e+21             45.670250          ...
#
#        Wet Gypsum Target (%)  Wet Gypsum Usage (%)  Wet Broke Target (%)  \
# count                   4275                4275.0                  4275
# unique                     2                   NaN                     6
# top                  No Data                   NaN               No Data
# freq                    3149                   NaN                  3149
# mean                     NaN                   0.0                   NaN
# std                      NaN                   0.0                   NaN
# min                      NaN                   0.0                   NaN
# 25%                      NaN                   0.0                   NaN
# 50%                      NaN                   0.0                   NaN
# 75%                      NaN                   0.0                   NaN
# max                      NaN                   0.0                   NaN
#
#        Wet Broke Usage (%)  Dust Target (%) Dust Usage (%)  Broke Target (%)  \
# count          4275.000000             4275    4275.000000              4275
# unique                 NaN                7            NaN                 5
# top                    NaN          No Data            NaN           No Data
# freq                   NaN             3149            NaN              3149
# mean              0.792902              NaN      12.687469               NaN
# std               3.276198              NaN      33.573087               NaN
# min              -0.000856              NaN       0.000077               NaN
# 25%               0.001372              NaN       0.329074               NaN
# 50%               0.005100              NaN       9.200419               NaN
# 75%               0.257903              NaN      13.778525               NaN
# max             100.278595              NaN     305.015625               NaN
#
#        Broke Usage (%)  Consistency Target (%) Consistency Actual (%)
# count      4275.000000             4275.000000                 4275.0
# unique             NaN                     NaN                    NaN
# top                NaN                     NaN                    NaN
# freq               NaN                     NaN                    NaN
# mean          2.382471                2.382471                    0.0
# std           4.061182                4.061182                    0.0
# min          -5.000071               -5.000071                    0.0
# 25%           0.000000                0.000000                    0.0
# 50%           0.003685                0.003685                    0.0
# 75%           4.528879                4.528879                    0.0
# max          60.165688               60.165688                    0.0
#
# [11 rows x 29 columns]

# %%
# Exclude all strings in any object column.
import numpy as np
df.describe(exclude=[np.object])
# Out:
#        Water Load (lb/MSF)  Wool Usage (%)  Wool Flow (lb/min)  \
# count          4275.000000     4275.000000         4275.000000
# mean           1088.845725      258.104949           23.932503
# std             128.663227      901.637413           27.605636
# min             943.770019        0.000000            0.000042
# 25%            1012.230042        4.163668            0.077812
# 50%            1041.569946       17.559425            0.470875
# 75%            1075.800049       20.963467           52.839138
# max            1486.560059     7352.957031          232.154449
#
#        Starch Usage (%)  Starch Flow (lb/min)  Clay Usage (%)  \
# count      4.275000e+03           4275.000000          4275.0
# mean       2.933942e+17             14.815349             0.0
# std        1.918313e+19             14.321005             0.0
# min       -4.254367e+01             -1.235398             0.0
# 25%        1.169661e+00             -0.168050             0.0
# 50%        9.867329e+00              6.758324             0.0
# 75%        1.034410e+01             29.850600             0.0
# max        1.254260e+21             45.670250             0.0
#
#        Clay Flow (lb/min)  Newsprint Usage (%)  Perlite Usage (%)  \
# count         4275.000000          4275.000000        4275.000000
# mean            -0.458074             9.059988          54.142210
# std              1.066906            12.851066         300.750791
# min             -1.237608             0.000000        -665.383606
# 25%             -1.206861             0.044219           1.708141
# 50%             -0.929585            10.594168          57.176479
# 75%             -0.127090            13.993915          58.816626
# max              3.207253           100.126297       15425.487300
#
#        Wet Clay Usage (%)  Wet Gypsum Usage (%)  Wet Broke Usage (%)  \
# count              4275.0                4275.0          4275.000000
# mean                  0.0                   0.0             0.792902
# std                   0.0                   0.0             3.276198
# min                   0.0                   0.0            -0.000856
# 25%                   0.0                   0.0             0.001372
# 50%                   0.0                   0.0             0.005100
# 75%                   0.0                   0.0             0.257903
# max                   0.0                   0.0           100.278595
#
#        Dust Usage (%)  Broke Usage (%)  Consistency Target (%)  \
# count     4275.000000      4275.000000             4275.000000
# mean        12.687469         2.382471                2.382471
# std         33.573087         4.061182                4.061182
# min          0.000077        -5.000071               -5.000071
# 25%          0.329074         0.000000                0.000000
# 50%          9.200419         0.003685                0.003685
# 75%         13.778525         4.528879                4.528879
# max        305.015625        60.165688               60.165688
#
#        Consistency Actual (%)
# count                  4275.0
# mean                      0.0
# std                       0.0
# min                       0.0
# 25%                       0.0
# 50%                       0.0
# 75%                       0.0
# max                       0.0

# %%
# Read a munged csv file.
FILE_TO_READ = 'thirteen_weeks_munged.csv'
df = pd.read_csv(FILE_TO_READ,
                 parse_dates=True,
                 index_col='Time')

# %%
# This results in the same as the exclude object code above.
pd.set_option('display.max_columns', 500)
df.describe()
# Out:
#        Water Load (lb/MSF)  Trim Board Density (lb/cft)  \
# count          4275.000000                  4271.000000
# mean           1088.845725                    11.694717
# std             128.663227                     0.481829
# min             943.770019                    10.542293
# 25%            1012.230042                    11.435856
# 50%            1041.569946                    11.598742
# 75%            1075.800049                    11.956731
# max            1486.560059                    22.305628
#
#        Trim Board Thickness (in)  Trim Board Weight (lb/sft)  Wool Target (%)  \
# count                4271.000000                 4267.000000      1126.000000
# mean                    0.598653                   57.725521        18.211368
# std                     0.009049                    2.953627         0.958561
# min                     0.299000                    0.000000        16.000000
# 25%                     0.594000                   56.299999        18.000000
# 50%                     0.596000                   57.099998        18.000000
# 75%                     0.602000                   58.599998        18.000000
# max                     0.630000                   67.900002        20.000000
#
#        Wool Usage (%)  Wool Flow (lb/min)  Starch Target (%)  \
# count     4275.000000         4275.000000             1126.0
# mean       258.104949           23.932503               10.0
# std        901.637413           27.605636                0.0
# min          0.000000            0.000042               10.0
# 25%          4.163668            0.077812               10.0
# 50%         17.559425            0.470875               10.0
# 75%         20.963467           52.839138               10.0
# max       7352.957031          232.154449               10.0
#
#        Starch Usage (%)  Starch Flow (lb/min)  Clay Target (%)  \
# count      4.275000e+03           4275.000000           1126.0
# mean       2.933942e+17             14.815349              0.0
# std        1.918313e+19             14.321005              0.0
# min       -4.254367e+01             -1.235398              0.0
# 25%        1.169661e+00             -0.168050              0.0
# 50%        9.867329e+00              6.758324              0.0
# 75%        1.034410e+01             29.850600              0.0
# max        1.254260e+21             45.670250              0.0
#
#        Clay Usage (%)  Clay Flow (lb/min)  Newsprint Target (%)  \
# count          4275.0         4275.000000                1126.0
# mean              0.0           -0.458074                  14.0
# std               0.0            1.066906                   0.0
# min               0.0           -1.237608                  14.0
# 25%               0.0           -1.206861                  14.0
# 50%               0.0           -0.929585                  14.0
# 75%               0.0           -0.127090                  14.0
# max               0.0            3.207253                  14.0
#
#        Newsprint Usage (%)  Perlite Target (%)  Perlite Usage (%)  \
# count          4275.000000         1126.000000        4275.000000
# mean              9.059988           57.788632          54.142210
# std              12.851066            0.958561         300.750791
# min               0.000000           56.000000        -665.383606
# 25%               0.044219           58.000000           1.708141
# 50%              10.594168           58.000000          57.176479
# 75%              13.993915           58.000000          58.816626
# max             100.126297           60.000000       15425.487300
#
#        Wet Clay Target (%)  Wet Clay Usage (%)  Wet Gypsum Target (%)  \
# count               1126.0              4275.0                 1126.0
# mean                   0.0                 0.0                    0.0
# std                    0.0                 0.0                    0.0
# min                    0.0                 0.0                    0.0
# 25%                    0.0                 0.0                    0.0
# 50%                    0.0                 0.0                    0.0
# 75%                    0.0                 0.0                    0.0
# max                    0.0                 0.0                    0.0
#
#        Wet Gypsum Usage (%)  Wet Broke Target (%)  Wet Broke Usage (%)  \
# count                4275.0           1126.000000          4275.000000
# mean                    0.0              0.517762             0.792902
# std                     0.0              1.586371             3.276198
# min                     0.0              0.000000            -0.000856
# 25%                     0.0              0.000000             0.001372
# 50%                     0.0              0.000000             0.005100
# 75%                     0.0              0.000000             0.257903
# max                     0.0              8.000000           100.278595
#
#        Dust Target (%)  Dust Usage (%)  Broke Target (%)  Broke Usage (%)  \
# count      1126.000000     4275.000000       1126.000000      4275.000000
# mean         12.791297       12.687469          7.989343         2.382471
# std           1.591074       33.573087          0.376973         4.061182
# min           8.000000        0.000077          6.000000        -5.000071
# 25%          12.000000        0.329074          8.000000         0.000000
# 50%          14.000000        9.200419          8.000000         0.003685
# 75%          14.000000       13.778525          8.000000         4.528879
# max          15.000000      305.015625         12.000000        60.165688
#
#        Consistency Target (%)  Consistency Actual (%)
# count             4275.000000                  4275.0
# mean                 2.382471                     0.0
# std                  4.061182                     0.0
# min                 -5.000071                     0.0
# 25%                  0.000000                     0.0
# 50%                  0.003685                     0.0
# 75%                  4.528879                     0.0
# max                 60.165688                     0.0
